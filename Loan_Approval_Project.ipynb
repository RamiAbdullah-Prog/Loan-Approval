# %% [markdown]
#      Data_LoanApproval

# %% [markdown]
# ### **Project: Loan Eligibility Prediction for Dream Housing Finance**
#
# ---
#
# ### **Project Description:**
#
# This project focuses on analyzing loan application data from Dream Housing Finance to predict loan eligibility for customers. The aim is to develop a machine learning model that can automate the process of determining whether a loan application is likely to be approved, based on a range of customer attributes and financial details.
#
# By analyzing factors such as:
#
# - **Applicant and coapplicant income**
# - **Credit history**
# - **Loan amount**
# - **Demographic details (e.g., gender, marital status, dependents, property area)**
#
# we aim to create a predictive solution that can help the company streamline its loan approval process and efficiently target eligible customers.
#
# ---
#
# ### **Objectives:**
#
# 1. **Data Cleaning:**
#
#    - Handle missing values and outliers to ensure a clean dataset for analysis and modeling.
#
# 2. **Data Visualization:**
#
#    - Create visualizations to identify key trends and patterns in the loan application data, focusing on factors that influence loan eligibility.
#
# 3. **Correlation and Feature Analysis:**
#
#    - Explore the relationships between various features such as income, credit history, and property area to determine their impact on loan approval.
#
# 4. **Encoding and Normalization:**
#
#    - Prepare the dataset by encoding categorical variables and normalizing numerical data for further predictive modeling.
#
# ---
#
# ### **Dataset Overview:**
#
# The dataset consists of loan application records from Dream Housing Finance, including details such as:
#
# - **Loan ID**: Unique identifier for each loan application.
# - **Gender**: Gender of the applicant (Male/Female).
# - **Marital Status**: Whether the applicant is married (Yes/No).
# - **Dependents**: Number of dependents.
# - **Education**: Education level of the applicant (Graduate/Undergraduate).
# - **Self-Employed**: Employment status of the applicant (Yes/No).
# - **ApplicantIncome**: Income of the applicant.
# - **CoapplicantIncome**: Income of the coapplicant.
# - **LoanAmount**: Loan amount requested (in thousands).
# - **Loan_Amount_Term**: Loan term duration (in months).
# - **Credit_History**: Indicator of credit history (meets guidelines or not).
# - **Property_Area**: Type of property area (Urban/Semi-Urban/Rural).
# - **Loan_Status**: Target variable indicating loan approval status (Yes/No).
#
# This comprehensive data provides a solid foundation for analyzing loan eligibility factors and building a robust prediction model.
#
# ---
#
# ### **Analysis Steps:**
#
# ⓵ **Data Cleaning:**
#
#    - Handle missing values and detect outliers to ensure data quality.
#
# ⓶ **Data Exploration and Visualization:**
#
#    - Analyze demographic and financial variables to identify patterns influencing loan eligibility.
#
# ⓷ **Feature Engineering and Encoding:**
#
#    - Transform categorical variables and normalize numerical data for accurate analysis and model training.
#
# ⓸ **Answer Key Business Questions:**
#
#    ### **Business Questions:**
#
#
#   1. **What is the relationship between the applicant’s income and the requested loan amount?**
#     - Does an increase in the applicant’s income correlate with a higher loan amount requested?
#
#   2. **What is the impact of credit history on the likelihood of loan approval?**
#     - Do loans with applicants who have a good credit history have a higher chance of being approved?
#
#   3. **Which geographical regions have higher approval rates for loans?**
#     - Are urban areas more likely to have loan approvals compared to semi-urban or rural areas?
#
#
#
# ---
#
# ### **Required Libraries:**
#
# - **pandas**
# - **matplotlib**
# - **seaborn**
# - **sklearn**
#
# ---

# %% [markdown]
# ## **Importing libarires**
#
# ####  ❐ We start by importing the necessary libraries for data analysis and visualization :
#
# **`numpy`**
#
# - A library for numerical operations.
#
#
# **`pandas`**
#
# - A powerful library for data manipulation and analysis.
#
#
# **`seaborn`**
#
# - A library for statistical data visualization.
#
#
# **`matplotlib`**
#
# -  A library for creating static, animated, and interactive visualizations.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ---

# %% [markdown]
# ## **Reading Data**

# %% [markdown]
# #### ❐ We read the data from a CSV file :

# %%
df = pd.read_csv('/content/drive/MyDrive/Data File/Data_LoanApproval_train_03.csv')

# %% [markdown]
# #### ❐  Display the first 5 rows of the data to confirm correct loading

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## **Displaying Basic Information About the Data**
#
# **`data.info() :`**
#
# - Displays general information about the DataFrame, such as data types and non-null counts.
#
# **`data.describe().T :`**
#
# - Provides descriptive statistics for numerical columns.
#
# **`data.shape` :**
#
# - Displays the number of rows and the number of columns.
#
# **`data.columns` :**
#
# - Displays the names of the columns in the DataFrame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 513 entries, 0 to 512
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            513 non-null    object
#  1   Gender             503 non-null    object
#  2   Married            510 non-null    object
#  3   Dependents         501 non-null    object
#  4   Education          513 non-null    object
#  5   Self_Employed      486 non-null    object
#  6   ApplicantIncome    513 non-null    int64
#  7   CoapplicantIncome  513 non-null    float64
#  8   LoanAmount         495 non-null    float64
#  9   Loan_Amount_Term   499 non-null    float64
#  10  Credit_History     470 non-null    float64
#  11  Property_Area      513 non-null    object
#  12  Loan_Status        513 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 52.2+ KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       513.000000         513.000000  495.000000        499.000000
# mean       5497.013645        1537.364366  144.739394        343.118236
# std        6486.147388        2144.079038   83.200278         63.375911
# min         150.000000           0.000000   17.000000         12.000000
# 25%        2876.000000           0.000000  100.000000        360.000000
# 50%        3846.000000        1210.000000  127.000000        360.000000
# 75%        5746.000000        2283.000000  163.000000        360.000000
# max       81000.000000       20000.000000  700.000000        480.000000
#
#        Credit_History
# count      470.000000
# mean         0.846809
# std          0.360556
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.shape
# Out:
# (513, 13)

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %% [markdown]
# ## Result :
#
# - The data is a Pandas DataFrame containing 513 rows and 13 columns.
# - The column data types include text (object), integers (int64), and floating-point numbers (float64).
#
# ## Here is a brief summary :
#
# 1. Columns fully complete (`no missing values`) :
#
#
#     Loan_ID, Education, ApplicantIncome, CoapplicantIncome, Property_Area, Loan_Status.
#
# 2. Columns not complete (`with missing values`) :
#
#
#     Gender, Married, Dependents, Self_Employed, LoanAmount, Loan_Amount_Term, and Credit_History.

# %% [markdown]
# ---

# %% [markdown]
# ## **Handling Missing Values**

# %% [markdown]
# #### ❐ Displaying Missing Values
#
#     This shows the missing values in each column.

# %%
missing_values = df.isnull().sum()
missing_columns = missing_values[missing_values > 0]
missing_columns
# Out:
# Gender              10
# Married              3
# Dependents          12
# Self_Employed       27
# LoanAmount          18
# Loan_Amount_Term    14
# Credit_History      43
# dtype: int64

# %% [markdown]
# #### ❐ Filling Null Values

# %% [markdown]
# - Fill missing values for categorical columns using the most common value.
#
# #  ⭣

# %%
df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])
df['Married'] = df['Married'].fillna(df['Married'].mode()[0])
df['Dependents'] = df['Dependents'].fillna(df['Dependents'].mode()[0])
df['Self_Employed'] = df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])

# %% [markdown]
# - Fill missing values for numerical columns.
#
# #  ⭣

# %%
df['LoanAmount'] = df['LoanAmount'].fillna(df['LoanAmount'].mean())
df['Loan_Amount_Term'] = df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
df['Credit_History'] = df['Credit_History'].fillna(df['Credit_History'].mode()[0])

# %% [markdown]
# - Verify that all missing values have been correctly filled.
#
# #  ⭣

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# ---
#
# ## **Description of Missing Data Handling**
#
# ### **1. Categorical Columns:**
#
# - **Columns affected:**
#
#   - Gender
#   - Marital Status
#   - Dependents
#   - Self-Employed
#
# - **Handling method:**
#
#   Missing values in these categorical columns were filled using the **most common value** (mode) for each column.
#
# ---
#
# ### **2. Numerical Columns:**
#
# - **Columns affected:**
#
#   - Loan Amount
#   - Loan Amount Term
#
# - **Handling method:**
#
#   Missing values in these numerical columns were filled using the **mean** (average) value for each column.
#
# ---
#
# ### **3. Credit History Column:**
#
# - **Column affected:**
#
#   - Credit History
#
# - **Handling method:**
#
#   Since this column contains binary data (0 and 1), missing values were filled with the **most common value** (mode) to maintain consistency in the data.
#
# ---
#
# ## **Result:**
#
# - All missing values have been successfully filled.
# - The dataset is now free of any **null** or **missing** values.
#
# ---

# %% [markdown]
# # **Dividing the Data into two sections :**
#
# ## - categorical data
#
# ## - numerical data
#
#
#
# ---

# %% [markdown]
# ## **❐ First section: numerical data**
#
#     Creates a new DataFrame containing only the columns with numerical values.

# %%
num = df.select_dtypes(include=['int64' , 'float64'])
num
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0  144.739394             360.0
# 1               4583             1508.0  128.000000             360.0
# 2               3000                0.0   66.000000             360.0
# 3               2583             2358.0  120.000000             360.0
# 4               6000                0.0  141.000000             360.0
# ..               ...                ...         ...               ...
# 508             2479             3013.0  188.000000             360.0
# 509            13262                0.0   40.000000             360.0
# 510             3598             1287.0  100.000000             360.0
# 511             6065             2004.0  250.000000             360.0
# 512             3283             2035.0  148.000000             360.0
#
#      Credit_History
# 0               1.0
# 1               1.0
# 2               1.0
# 3               1.0
# ...

# %% [markdown]
# ## **❐ Second section: categorical data**
#
#     Creates a new DataFrame containing columns that represent categorical values.

# %%
for i in df.columns :
  x = df[i].value_counts()
  print(f'{i} = {len(x)}')
# Out:
# Loan_ID = 513
# Gender = 2
# Married = 2
# Dependents = 4
# Education = 2
# Self_Employed = 2
# ApplicantIncome = 426
# CoapplicantIncome = 244
# LoanAmount = 184
# Loan_Amount_Term = 11
# Credit_History = 2
# Property_Area = 3
# Loan_Status = 2

# %%
Cat = df[['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status']]
Cat
# Out:
#      Gender Married Dependents     Education Self_Employed  Loan_Amount_Term  \
# 0      Male      No          0      Graduate            No             360.0
# 1      Male     Yes          1      Graduate            No             360.0
# 2      Male     Yes          0      Graduate           Yes             360.0
# 3      Male     Yes          0  Not Graduate            No             360.0
# 4      Male      No          0      Graduate            No             360.0
# ..      ...     ...        ...           ...           ...               ...
# 508    Male     Yes          0      Graduate           Yes             360.0
# 509  Female      No          1      Graduate            No             360.0
# 510    Male      No          0  Not Graduate            No             360.0
# 511    Male     Yes          1      Graduate            No             360.0
# 512    Male     Yes          2      Graduate            No             360.0
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Data Visualization
#
#
# ##❐ The First Section : Numerical Data
#
#
# In this step :
#
#  📍 we will perform visualization of the numerical data to understand the relationships between different variables.
#
#  📍 Visualization helps uncover patterns and trends in the data, making it easier to make data-driven decisions.
#
#
#  📍 This analysis will allow us to draw important patterns and relationships that may affect our final results.
#
#
#
# ---

# %% [markdown]
# ##We will start by conducting the following :
#
# ###**🔻 Correlation Matrix :**
#
#     To evaluate the relationships between different numerical variables the correlation matrix has been computed.
#     This matrix provides insights into how the variables are related to each other
#     revealing ( positive and negative relationships or a lack of correlation)
#
# ❇ value close to **+1** indicates a strong positive relationship
#
# ❇ value close to **-1** indicates a strong negative relationship
#
# ❇ Values around **0** no linear correlation between the variables

# %%
Cor = num.corr()
Cor
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.111976    0.576127
# CoapplicantIncome        -0.111976           1.000000    0.225263
# LoanAmount                0.576127           0.225263    1.000000
# Loan_Amount_Term         -0.070223           0.014132    0.030647
# Credit_History           -0.035742          -0.017273   -0.021719
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome           -0.070223       -0.035742
# CoapplicantIncome          0.014132       -0.017273
# LoanAmount                 0.030647       -0.021719
# Loan_Amount_Term           1.000000        0.018496
# Credit_History             0.018496        1.000000

# %% [markdown]
# ###**🔻 Heat Map :**
#
#     To visually represent the correlation matrix, a heatmap has been created to illustrate
#     the relationships between the numerical variables.

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(Cor, annot=True, linewidths=0.6)
plt.title('Heatmap of Correlation Matrix')
plt.show()

# %% [markdown]
# ---
#
# ### **📊 Summary of Correlation Matrix and Heatmap Results**
#
# ---
#
# #### **1. Applicant Income**
#
# - **Correlation**: Moderate positive relationship with Loan Amount (0.576).
# - **Interpretation**: As applicant income increases, the loan amount they can receive tends to increase as well.
# - **Key Insight**: **Applicant Income** is the **most influential factor** on loan amount.
#
#
# ---
#
# #### **2. Coapplicant Income**
#
# - **Correlation**: Weak relationship with Loan Amount (0.225).
# - **Interpretation**: Coapplicant income has a small effect on the loan amount, with a weak correlation.
# - **Key Insight**: **Coapplicant Income** has **minimal effect** on loan amount.
#
#
# ---
#
# #### **3. Loan Amount Term**
#
# - **Correlation**: No strong correlations with other variables.
# - **Interpretation**: Loan term does not significantly affect the loan amount or any other variables.
# - **Key Insight**: **Loan Amount Term** has **minimal influence**.
#
# ---
#
# #### **4. Credit History**
#
# - **Correlation**: No notable relationships with other variables.
# - **Interpretation**: Credit history does not appear to significantly influence loan amount or other variables.
# - **Key Insight**: **Credit History** has **negligible impact**.
#
#
# ---
#
# ### **📌 Conclusion**
#
# - **Most Influential Factor**: **Applicant Income** is the most important factor in determining loan amount, with a moderate positive correlation.
# - **Other Factors**: Coapplicant income, loan amount term, and credit history have weak or negligible effects.
#
# ---
#
# ### **📉 Visual Summary**
#
# To illustrate these relationships more clearly, a **Correlation Matrix Heatmap** can be used to visualize the strength and direction of correlations.
#
# ---
#
# ### **📊 Interpretation of Correlations**
#
# | **Type**              | **Description**                                     |
# |-----------------------|-----------------------------------------------------|
# | **Positive Correlation**| As one factor increases, the other also increases.
# |
# | **Weak Correlation**   | A small or minimal relationship exists between factors.
# |
# | **No Correlation**     | No significant relationship between factors.
# |
#
# ---
#
# ### **Additional Notes**
#
# - Information has been divided into **paragraphs** with **tables** included for clearer presentation of the correlation data.
# - Key insights and conclusions have been highlighted for easier understanding.
#
# ---

# %% [markdown]
# ###**🔻 Scatter Plots :**
#
#     Creates a scatter plot to show the relationship between the target and Numerical Data Columns.

# %% [markdown]
# ##1- `Applicant Income and Loan Amount with Loan_Status`

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='ApplicantIncome', y='LoanAmount', hue='Loan_Status')
plt.title('Applicant Income vs Loan Amount by Loan Status')
plt.xlabel('Applicant Income')
plt.ylabel('Loan Amount')
plt.show()

# %% [markdown]
# ### Scatter Plot Documentation: Relationship Between Applicant Income and Loan Amount
#
# - **Weak positive correlation** between **income** and **loan amount**: Higher-income applicants tend to apply for larger loans.
# - **Significant variation** in loan amounts: Loan amounts vary widely, regardless of income level.
# - **Both loan statuses (approved/rejected)** appear across all income and loan amount ranges.
# - **Income alone** may not be a strong predictor of **loan approval**.
#
#
# ---

# %% [markdown]
# ##2- `Loan Amount and Credit History with Loan_Status`

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='LoanAmount', y='Credit_History', hue='Loan_Status')
plt.title('Loan Amount vs Credit History by Loan Status')
plt.xlabel('Loan Amount')
plt.ylabel('Credit History')
plt.show()

# %% [markdown]
# ##3- `Coapplicant Income and Loan Amount Term with Loan_Status`

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='CoapplicantIncome', y='Loan_Amount_Term', hue='Loan_Status')
plt.title('Coapplicant Income vs Loan Amount Term by Loan Status')
plt.xlabel('Coapplicant Income')
plt.ylabel('Loan Amount Term')
plt.show()

# %% [markdown]
# ### Scatter Plot Documentation: Relationship Between Coapplicant Income and Loan Amount Term
#
# - **No strong correlation** between **coapplicant income** and **loan amount term** or **loan approval status**.
# - The points are randomly scattered across the plot, showing no clear patterns.
# - The points are color-coded based on loan status:
#   - **Blue**: Loan approved.
#   - **Orange**: Loan denied.
# - The plot suggests that **coapplicant income** does not significantly influence the loan amount term or whether the loan is approved.
#
# ---

# %% [markdown]
# ## **🔻 Histogram**
#
#     Plots histograms for numerical data to visualize their distributions and understand the underlying frequency of the data.

# %%
plt.figure(figsize=(12, 6))

sns.histplot(data=df, x='ApplicantIncome', hue='Loan_Status', kde=True)
plt.title('Histogram: Loan_Status vs ApplicantIncome')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Histogram Documentation: Distribution of Applicant Income by Loan Status
#
# - This histogram shows the distribution of **applicant income** for individuals who were approved for a loan (**Loan_Status=Y**) and those who were not approved (**Loan_Status=N**).
# - The **ApplicantIncome** distribution is **right-skewed**, indicating that most applicants have lower incomes.
# - A higher number of applicants with **lower income** were approved for loans, suggesting that **income** may have an impact on loan approval status.
# - The graph reveals a relationship between **applicant income** and **loan approval status**.
#
# ---

# %%
plt.figure(figsize=(12, 6))

sns.histplot(data=df, x='LoanAmount', hue='Loan_Status', kde=True)
plt.title('Histogram: Loan_Status vs LoanAmount')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Histogram Documentation: Distribution of Loan Amounts by Loan Status
#
# - This histogram shows the distribution of **loan amounts** for loans that were approved ('Y') and those that were not approved ('N').
# - The distribution of loan amounts is **right-skewed** for both approved and non-approved loans, meaning there are more loans with lower amounts than higher amounts.
# - There is a **slightly higher concentration** of approved loans around the **100 loan amount** mark compared to non-approved loans.

# %% [markdown]
# ---

# %% [markdown]
# # Handling Outliers
#
# ##**Step 1: Box Plot for Numeric Columns**
#
# In this step, we create box plots for all numeric columns in the dataset to visually identify potential outliers. The box plot provides a graphical representation of the distribution of the data, highlighting the median, quartiles, and any data points that fall outside the expected range.
#
# ---

# %%
num.plot (kind = 'box' , subplots= True , figsize=(15,5) , layout = None)
# Out:
# ApplicantIncome         Axes(0.125,0.11;0.133621x0.77)
# CoapplicantIncome    Axes(0.285345,0.11;0.133621x0.77)
# LoanAmount            Axes(0.44569,0.11;0.133621x0.77)
# Loan_Amount_Term     Axes(0.606034,0.11;0.133621x0.77)
# Credit_History       Axes(0.766379,0.11;0.133621x0.77)
# dtype: object

# %% [markdown]
# ## Result :
#
# We decided not to remove outliers at this stage, because the data size is small
#
# and deleting outliers would result in significant data loss.
#
# Alternatively, we may consider alternative ways to deal with outliers in later stages of analysis if necessary.

# %% [markdown]
# ---
#
#
# ### **❐ The Second Section: Categorical Data**
#
# In this step:
#
#  📍 We will perform visualization of the categorical data to understand the distribution and relationships among different categorical variables.
#
#  📍 Visualization aids in revealing patterns, trends, and potential insights from categorical data, facilitating better data-driven decisions.
#
#  📍 This analysis will help us uncover significant associations and characteristics that may influence our final results.
#
#     This will mark the beginning of our exploration of categorical data, paving the way for further analysis and insights

# %% [markdown]
# ## We will start by conducting the following:
#
# ### **🔻 Pie Charts:**
#
#     To visualize the distribution of each categorical variable, pie charts will be created.
#     These charts will provide an intuitive representation of the proportions of each category within the variables.

# %%
for i in Cat.columns :
  x = Cat[i].value_counts()
  plt.figure(figsize=(8,6))
  plt.pie( x , labels=x.index , autopct='%1.1f%%' , wedgeprops= {'edgecolor': 'white'} )
  plt.title(i)

# %% [markdown]
# ---

# %% [markdown]
# ### **🔻 Cross-tabulation & Bar Plots 🔻**
#
#     ⭑ Cross-tabulation will be performed to analyze the interactions between two categorical variables.
#     This will help in understanding the joint distribution and relationships between the variables.
#
#     ⭑ Bar plots will be utilized to compare the frequencies of categories within individual variables,
#     as well as to explore relationships between two categorical variables.
#     This visualization will allow for easy comparison of counts and proportions.

# %%
cancellation_comparison= pd.crosstab(df['Married'] , df['Loan_Status'])
cancellation_comparison.plot(kind='bar', color=['#4CAF50', '#F44336'])
plt.title('Count Plot: Loan_Status vs Married')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ### Bar Chart Documentation: Relationship Between Marital Status and Loan Status
#
# - This bar chart shows the relationship between **marital status** and **loan status**.
# - It indicates that a higher number of **married individuals** have approved loans (**Loan_Status=Y**) compared to those who are **not married**.
#
# ---

# %%
cancellation_comparison= pd.crosstab(df['Education'] , df['Loan_Status'])
cancellation_comparison.plot(kind='bar',color=['#ffbb78', '#aec7e8'])
plt.title('Count Plot: Loan_Status vs Education')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ### Count Plot Documentation: Loan Status vs Education
#
# - This count plot shows the relationship between **loan status** and **education**.
# - It reveals that there are more **graduates** who have taken a loan compared to those who are not graduates.
# - It also shows that there are more people who **haven't taken a loan** than those who have, regardless of their education status.
#
# ---

# %% [markdown]
# ##**🔻 Count plot**
#
#     Creating countplots for each categorical column to analyze
#     the distribution of loan status ('Loan_Status') across different categories.

# %%
Cat.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Loan_Status', hue='Gender', data=df)
plt.title('Count Plot: Loan_Status vs Gender')
plt.show()

# %% [markdown]
# ### Count Plot Documentation: Loan Status vs Gender
#
# - The plot shows that **more men** have been approved for loans compared to **women**.
#
# - **Women** show a higher rejection rate for loans than men.
#
# - This could indicate a potential **bias** in the loan approval process based on gender.
#
# - It’s important to investigate **other factors** like **income** or **credit score**
#
#  to understand the reasons behind this difference before drawing conclusions.
#
# ---

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Loan_Status', hue='Property_Area', data=df)
plt.title('Count Plot: Loan_Status vs Property_Area')
plt.show()

# %% [markdown]
# ### Count Plot Documentation: Loan Status vs Property Area
#
# - The plot shows the relationship between **loan status** and **property area**.
# - A higher proportion of people living in **semiurban areas** have been approved for loans (**Loan_Status=Y**) compared to those in **rural** or **urban areas**.
# - Fewer individuals in **semiurban areas** have been denied loans.
# - This suggests that **property area** could be a factor in determining **loan approval**.

# %% [markdown]
# ---

# %% [markdown]
# # **Answering Business Questions Related to Data Analysis**

# %% [markdown]
# ---
# ## **Question 1 :**
#
# ### What is the relationship between the applicant’s income and the requested loan amount ?
# ---

# %%
Cor
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.111976    0.576127
# CoapplicantIncome        -0.111976           1.000000    0.225263
# LoanAmount                0.576127           0.225263    1.000000
# Loan_Amount_Term         -0.070223           0.014132    0.030647
# Credit_History           -0.035742          -0.017273   -0.021719
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome           -0.070223       -0.035742
# CoapplicantIncome          0.014132       -0.017273
# LoanAmount                 0.030647       -0.021719
# Loan_Amount_Term           1.000000        0.018496
# Credit_History             0.018496        1.000000

# %%
sns.heatmap(Cor, annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df , x='ApplicantIncome', y='LoanAmount' )
plt.title("Scatter plot between Applicant Income and Loan Amount")
plt.xlabel("Applicant Income")
plt.ylabel("Loan Amount")
plt.show()

# %% [markdown]
# ---
#
# ### Analysis of the Relationship Between Applicant Income and Loan Amount
#
# We observe that:
#
# - **Applicant Income and Loan Amount**: The correlation coefficient between applicant income and loan amount is **0.5761**, indicating a **moderate to strong positive relationship** between the two variables.
#
# This analysis shows that:
#
# - **As applicant income increases**, the loan amount requested tends to **increase as well**.
#
# ### Reason:
# Applicants with higher incomes are more likely to request larger loan amounts, as they feel more confident in their ability to repay. Therefore, income plays a significant role in determining the amount of the loan requested.

# %% [markdown]
# ---
# ## **Question 2 :**
#
# ### What is the impact of credit history on the likelihood of loan approval?
#
# ---

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Credit_History', hue='Loan_Status', data=df)
plt.title("Loan Approval Based on Credit History")
plt.xlabel("Credit History")
plt.ylabel("Count of Loans")
plt.show()

# %%
credit_history_percentage = df.groupby('Credit_History')['Loan_Status'].value_counts(normalize=True) * 100
credit_history_percentage
# Out:
# Credit_History  Loan_Status
# 0.0             N              91.666667
#                 Y               8.333333
# 1.0             Y              79.138322
#                 N              20.861678
# Name: proportion, dtype: float64

# %% [markdown]
# ---
#
# ### Interpretation of Credit History and Loan Approval
#
# We observe the following:
#
# - **Credit History = 0 (Poor Credit History)**:
#   - **91.67%** of individuals with a poor credit history (0) had their loan applications **rejected** (Loan_Status = N).
#   - Only **8.33%** were **approved** (Loan_Status = Y).
#
# - **Credit History = 1 (Good Credit History)**:
#   - **79.14%** of individuals with a good credit history (1) had their loan applications **approved** (Loan_Status = Y).
#   - **20.86%** were **rejected** (Loan_Status = N).
#
# ### Conclusion:
# - **Good credit history (1)** is strongly associated with a higher chance of loan approval (79.14% approval rate compared to 8.33% for those with a poor credit history).
# - On the other hand, individuals with a **poor credit history (0)** are more likely to have their loan applications **rejected**.
#
# ---

# %% [markdown]
# ---
# ## **Question 3 :**
#
# ###  Which geographical regions have higher approval rates for loans?
#
#
# ---

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Property_Area', hue='Loan_Status', data=df)
plt.title("Loan Approval by Property Area")
plt.xlabel("Property Area")
plt.ylabel("Count of Loans")
plt.show()

# %%
property_area_approval = df.groupby('Property_Area')['Loan_Status'].value_counts(normalize=True) * 100
property_area_approval
# Out:
# Property_Area  Loan_Status
# Rural          Y              60.000000
#                N              40.000000
# Semiurban      Y              79.687500
#                N              20.312500
# Urban          Y              65.340909
#                N              34.659091
# Name: proportion, dtype: float64

# %% [markdown]
# ---
#
# ### Interpretation of the Impact of Geographical Regions on Loan Approval
#
# Conclusion:
#
# - **Semiurban areas** have the highest loan approval rate, with **79.69%** of applicants in these areas getting **approved**.
# - **Urban areas** come second, with a loan approval rate of **65.34%**.
# - **Rural areas** have the lowest approval rate, with only **60%** of applicants getting their loans **approved**.
#
# ---

# %% [markdown]
# ---

# %% [markdown]
# # Encoding
#
# ❐ **Objective**: Convert categorical columns into a suitable numerical format to enhance model performance.
#
# ❐ **Purpose**: Improve the performance of the data analysis model by representing categorical values as numbers.

# %%
df

# %%
df = df.drop(columns=['Loan_ID'])

# %% [markdown]
# ---
#
# ## Encoding Type Used
#
#
# **Label Encoding**
# We will use Label Encoding to transform categorical values into numerical representations, facilitating better understanding by machine learning models.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE = LabelEncoder()

df['Gender']=LE.fit_transform(df['Gender'])
df['Married']=LE.fit_transform(df['Married'])
df['Education']=LE.fit_transform(df['Education'])
df['Dependents']=LE.fit_transform(df['Dependents'])
df['Loan_Status']=LE.fit_transform(df['Loan_Status'])
df['Property_Area']=LE.fit_transform(df['Property_Area'])
df['Self_Employed']=LE.fit_transform(df['Self_Employed'])
df['Credit_History']=LE.fit_transform(df['Credit_History'])

# %%
df

# %% [markdown]
# ---
#
# ### Conclusion of Encoding Step
#
# - Successfully transformed categorical features into numerical values.
# - Changes were verified in the original dataset, preparing for the next step (scaling).
#
# ---

# %% [markdown]
# ## **Scalling**
#
# ❐ Scaling procedure for data to improve the performance of statistical models and machine learning
#
# by standardizing the range of values, enhancing accuracy and efficiency in analysis

# %%
df

# %% [markdown]
# ##**Z-score scaling**
#
#
# We will choose **Z-score scaling**  because it provides an effective way to deal with outliers in the data.
#
# The goal of this process is to improve the accuracy of statistical models and machine learning by transforming
#
# the data to a normal distribution, which enhances the models' performance and makes them more reliable.

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)

# %%
df = pd.DataFrame(df_scaled, columns=df.columns)

# %%
df

# %% [markdown]
# ---

# %% [markdown]
# # **Final Data Processing Documentation**
#
# After completing the data processing steps, it has been confirmed that the dataset is now ready for modeling purposes.
#
# **Completed Steps:**
#
# 1. **Data Validation:**
# - The columns in the dataset were reviewed to ensure that there were no non-numeric values.
# - The text columns were coded, making all values ​​numeric.
#
# 2. **Scaling:**
# - **Standardized Score** was applied to all numeric columns.
# - The results showed a balanced distribution with both negative and positive values, indicating that all features are now on the same scale.
#
# 3. **Validation Results:**
# - It was verified that all values ​​fall within an appropriate range, and no columns contain illogical values.
# - Our data is now clean and logical, facilitating future analyses.
#
# **Conclusion:**
#
# After performing all the necessary steps, the dataset is prepared for the next stage, which is **Modeling**.
#
# We are confident that this data will contribute to accurate and reliable results in future analyses.
